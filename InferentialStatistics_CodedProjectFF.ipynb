# %% [markdown]
# ## Problem 2

# %% [markdown]
# The breaking strength of gunny bags used for packaging cement is normally distributed with a mean of 5 kg per sq. centimeter and a standard deviation of 1.5 kg per sq. centimeter. The quality team of the cement company wants to know the following about the packaging material to better understand wastage or pilferage within the supply chain; Answer the questions below based on the given information; **(Provide an appropriate visual representation of your answers, without which marks will be deducted)**

# %% [markdown]
# ## Importing necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import scipy.stats as stats

# %% [markdown]
# **2.1	What proportion of the gunny bags have a breaking strength of less than 3.17 kg per sq cm?**

# %%
from scipy.stats import norm
mu=5
sigma=1.5
# cdf(X<3.17)
prop_one= round(norm.cdf(3.17,mu,sigma),4)
prop_one
print("The", round(prop_one*100, 2),'%', "proportion of the gunny bags has a breaking strength of less than 3.17 kg per sq cm")
prop_one
# Out:
# The 11.12 % proportion of the gunny bags has a breaking strength of less than 3.17 kg per sq cm
# 0.1112

# %%
# Visual representation for the answer
density=pd.DataFrame()
density["x"]=np.linspace(-1,11,100)
density["pdf"]=norm.pdf(density["x"],mu,sigma)
fig, ax = plt.subplots()
ax.plot(density["x"],density["pdf"], color="red")
plt.title("Normal Distribution") # set the title
plt.xlabel("Breaking strength of packaging in kg per sq. centimeter")
plt.ylabel("Probability")
plt.axvline(x=3.17, c="b")
x1=np.linspace(-1,3.17,50) 
plt.fill_between(x1,norm.pdf(x1,mu,sigma), color="b")
plt.show() # display the plot

# %% [markdown]
# **2.2 What proportion of the gunny bags have a breaking strength of at least 3.6 kg per sq cm.?**

# %%
from scipy.stats import norm
mu=5
sigma=1.5
# cdf(X>=3.6)
prop_two=round(1- norm.cdf(3.6,mu,sigma),4)

print("The", round(prop_two*100, 2),'%', "proportion of the gunny bags has a breaking strength of atleast 3.6 kg per sq cm")
prop_two
# Out:
# The 82.47 % proportion of the gunny bags has a breaking strength of atleast 3.6 kg per sq cm
# 0.8247

# %%
# Visual representation for the answer
density=pd.DataFrame()
density["x"]=np.linspace(-1,11,100)
density["pdf"]=norm.pdf(density["x"],mu,sigma)
fig, ax = plt.subplots()
ax.plot(density["x"],density["pdf"], color="red")
plt.title("Normal Distribution") # set the title
plt.xlabel("Breaking strength of packaging in kg per sq. centimeter")
plt.ylabel("Probability")
plt.axvline(x=3.6, c="b")
x1=np.linspace(3.6,11,50) 
plt.fill_between(x1,norm.pdf(x1,mu,sigma), color="b")
plt.show() # display the plot

# %% [markdown]
# **2.3 What proportion of the gunny bags have a breaking strength between 5 and 5.5 kg per sq cm.?**

# %%
from scipy.stats import norm
mu=5
sigma=1.5
# cdf(5<X<5.5)
prop_three=round(norm.cdf(5.5,mu,sigma)-norm.cdf(5,mu,sigma),4)

print("The", round(prop_three*100, 2),'%', "proportion of the gunny bags has a breaking strength between 5 and 5.5 kg per sq cm")
prop_three
# Out:
# The 13.06 % proportion of the gunny bags has a breaking strength between 5 and 5.5 kg per sq cm
# 0.1306

# %%
# Visual representation for the answer
density=pd.DataFrame()
density["x"]=np.linspace(-1,11,100)
density["pdf"]=norm.pdf(density["x"],mu,sigma)
fig, ax = plt.subplots()
ax.plot(density["x"],density["pdf"], color="red")
plt.title("Normal Distribution") # set the title
plt.xlabel("Breaking strength of packaging in kg per sq. centimeter")
plt.ylabel("Probability")
plt.axvline(x=5, c="b")
plt.axvline(x=5.5, c="b")
x1=np.linspace(5,5.5,50) 
plt.fill_between(x1,norm.pdf(x1,mu,sigma), color="b")
plt.show() # display the plot

# %% [markdown]
# **2.4 What proportion of the gunny bags have a breaking strength NOT between 3 and 7.5 kg per sq cm.?**

# %%
from scipy.stats import norm
mu=5
sigma=1.5
# 1-cdf(3<X<7.5)
prop_four=round(1-(norm.cdf(7.5,mu,sigma)-norm.cdf(3,mu,sigma)),4)
print("The", round(prop_four*100, 2),'%', "proportion of the gunny bags has a breaking strength NOT between 3 and 7.5 kg per sq cm")
prop_four
# Out:
# The 13.9 % proportion of the gunny bags has a breaking strength NOT between 3 and 7.5 kg per sq cm
# 0.139

# %%
# Visual representation for the answer
density=pd.DataFrame()
density["x"]=np.linspace(-1,11,100)
density["pdf"]=norm.pdf(density["x"],mu,sigma)
fig, ax = plt.subplots()
ax.plot(density["x"],density["pdf"], color="red")
plt.title("Normal Distribution") # set the title
plt.xlabel("Breaking strength of packaging in kg per sq. centimeter")
plt.ylabel("Probability")
plt.axvline(x=3, c="b")
plt.axvline(x=7.5, c="b")
x1=np.linspace(-1,3,50) 
plt.fill_between(x1,norm.pdf(x1,mu,sigma), color="b")
x2=np.linspace(7.5,11,50) # creating an array of 50 between min and 3.17
plt.fill_between(x2,norm.pdf(x2,mu,sigma), color="b")
plt.show() # display the plot

# %% [markdown]
# ## Problem 3

# %% [markdown]
# Zingaro stone printing is a company that specializes in printing images or patterns on polished or unpolished stones. However, for the optimum level of printing of the image, the stone surface has to have a Brinell's hardness index of at least 150. Recently, Zingaro has received a batch of polished and unpolished stones from its clients. Use the data provided to answer the following **(assuming a 5% significance level)**;

# %% [markdown]
# ## Import necessary libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import scipy.stats as stats

# %% [markdown]
# ## Step 1: Load the dataset

# %%
data = pd.read_csv('Zingaro_Company.csv')
# copying the data to another variable
df = data.copy()

# %% [markdown]
# ## Step 2: Overview of the data

# %%
df.head()
# Out:
#    Unpolished  Treated and Polished
# 0  164.481713            133.209393
# 1  154.307045            138.482771
# 2  129.861048            159.665201
# 3  159.096184            145.663528
# 4  135.256748            136.789227

# %% [markdown]
# * The dataset contains the details of the **Brinell's hardness index of both the unpolished and polished stones**

# %%
df.shape #shape of the data set gives number of rows and columns
# Out:
# (75, 2)

# %% [markdown]
# * The dataset contains the information about a sample of **75 stones**

# %%
df.info()  #checking the data types of columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75 entries, 0 to 74
# Data columns (total 2 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unpolished            75 non-null     float64
#  1   Treated and Polished  75 non-null     float64
# dtypes: float64(2)
# memory usage: 1.3 KB

# %% [markdown]
# * The columns `Unpolished`, and `Treated and Polished` are of float type (numerical)

# %%
df.describe()  #checking the statistical summary of the data
# Out:
#        Unpolished  Treated and Polished
# count   75.000000             75.000000
# mean   134.110527            147.788117
# std     33.041804             15.587355
# min     48.406838            107.524167
# 25%    115.329753            138.268300
# 50%    135.597121            145.721322
# 75%    158.215098            157.373318
# max    200.161313            192.272856

# %% [markdown]
# * Overall, the average Brinell's hardness index for the sample of 75 stones have increased by 10.2% to approximately 147.79 with treating and polishing of stones
#
# * The maximum Brinell's hardness index from polishing the stones is 192.27, which is 3.9% lesser than the maximum output from the not polishing the stones
#
# * The minimum Brinell's hardness index from polishing the stones has an increase by 122.13%
#
# * With polishing the stones, 50% of the stones have a hardness index of atleast 145.72, which has increased by 7.46% compared to not treating them
#
# * It can be seen that there is more variation in treating the stones as compared to not treating them

# %%
# visual analysis of Brinell's hardness index from unpolishing and polishing of stones
sns.boxplot(data=df[['Unpolished','Treated and Polished']],orient='h')
plt.xlabel('Brinell hardness index')
plt.show()

# %% [markdown]
# * The distribution of outputs for the two varieties of stones are different and a slight increase is observed in the median value of treating and polishing the stones as compared to not polishing them
#
# * The Brinell's hardness index of 75% of the stones remains the same both the two treatments, however the maximum value of unpolished is higher compared to the maximum value of polished varieties
#
# * Outliers can be observed in both varieties of stones, suggesting that some stones had unusually better or worse Brinell's hardness index than the others
#
# * A statistical test is used to justify that the unpolished stones are not suitable for printing

# %% [markdown]
#  ### 3.1 Zingaro has reason to believe that the unpolished stones may not be suitable for printing. Do you think Zingaro is justified in thinking so?

# %% [markdown]
# ### Let's write the null and alternative hypotheses

# %% [markdown]
# Zingaro stone printing company believes that the unpolished stones (one sample) may not be suitable for printing. The Brinell's hardness index of atleast 150 is considered to be the optimum level for printing of the image on the stone surface.
#
# Let $\mu$ be the optimum level of Brinell's hardness index
#
# The null hypothesis
# >$H_0: \mu >= 150$
#
# need to be tested against the alternate hypothesis
# >$H_a: \mu < 150$
#
# The Brinell's hardness index is measured on a continuous scale. The population is normally distributed and the sample size is 75 > 30. The population standard deviation is not known. The population being normally distributed, is there enough evidence at $\alpha = 0.05$ to support that the Zingaro's claim is false?
#
# **We can use T-test for this problem**

# %% [markdown]
# ### Let's find the p-value

# %%
#import the required functions
from scipy.stats import ttest_1samp

# calculate the test statistic and p-value
test_stat, p_value = ttest_1samp(df['Unpolished'], popmean = 150, alternative = 'less')
print('The p-value is ', p_value)
print('The test_stat is ', test_stat)
# Out:
# The p-value is  4.171286997419652e-05
# The test_stat is  -4.164629601426757

# %% [markdown]
# ### Insight
# As the p-value is much less than the level of significance, we can reject the null hypothesis, that is Brinells hardness index is not greater or equal to 150 for **Unpolished stones**. Hence, we do not have enough significance to conclude that the unpolished stones have the optimal Brinells hardness index.
# Thus, the Zingaro's claim that the unpolished stones not being suitable for printing of images is **TRUE**

# %% [markdown]
#  ### 3.2 Is the mean hardness of the polished and unpolished stones the same?

# %%
# find the sample means and sample standard deviations for the two samples
print('The mean Brinell hardness index for Unpolished stones is ' + str(df['Unpolished'].mean()))
print('The mean Brinell hardness index for Treated and Polished stones is ' + str(df['Treated and Polished'].mean()))
print('The standard deviation of Brinell hardness index for Unpolished stones is ' + str(round(df['Unpolished'].std(), 2)))
print('The standard deviation of Brinell hardness index for Treated and Polished stones is ' + str(round(df['Treated and Polished'].std(), 2)))
# Out:
# The mean Brinell hardness index for Unpolished stones is 134.11052653373332
# The mean Brinell hardness index for Treated and Polished stones is 147.78811718133335
# The standard deviation of Brinell hardness index for Unpolished stones is 33.04
# The standard deviation of Brinell hardness index for Treated and Polished stones is 15.59

# %% [markdown]
# ### Check for T-test assumptions

# %% [markdown]
# * Continuous data - Yes, the Brinell hardness index is measured on a continuous scale.
# * Normally distributed populations - Yes, we are informed that the populations are assumed to be normal.
# * Independent populations - As we are taking random samples for two different groups, the two samples are from two independent populations.
# * Unequal population standard deviations - As the sample standard deviations are different, the population standard deviations may be assumed to be different.
# * Random sampling from the population - Yes, we are informed that the collected sample a simple random sample.
#
# **We can use two sample T-test for this problem.**

# %% [markdown]
# ### Let's write the null and alternative hypotheses

# %% [markdown]
# Let $\mu_1, \mu_2$ be the mean Brinell hardness index values of **Unpolished** and **Treated and Polished** stones respectively.
#
# We will test the null hypothesis
#
# >$H_0:\mu_1=\mu_2$
#
# against the alternate hypothesis
#
# >$H_a:\mu_1>\mu_2$

# %%
#import the required functions
from scipy.stats import ttest_ind

# find the p-value
test_stat, p_value = ttest_ind(df['Unpolished'], df['Treated and Polished'].dropna(), equal_var = False, alternative = 'two-sided')
print('The p-value is ', p_value)
# Out:
# The p-value is  0.001588379295584306

# %% [markdown]
# ### Insight
# As the p-value (~0.0016) is less than the level of significance ($\alpha = 0.005$), we can reject the null hypothesis. Hence, we do not have enough evidence to support the claim that the unpolished and polished stones have the same population mean Brinell hardness index values. **So, the mean hardness of the polished and unpolished stones are not the same.**

# %% [markdown]
# ## Problem 4

# %% [markdown]
# Dental implant data: The hardness of metal implants in dental cavities depends on multiple factors, such as the method of implant, the temperature at which the metal is treated, the alloy used as well as the dentists who may favor one method above another and may work better in his/her favorite method. The response is the variable of interest.

# %% [markdown]
# ## Import necessary libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import scipy.stats as stats
from statsmodels.formula.api import ols # for n_way anova
from statsmodels.stats.anova import _get_covariance,anova_lm  # for n_way anova
# %matplotlib inline

# %% [markdown]
# ## Step 1: Load the dataset

# %%
datadental=pd.read_csv('Dental Hardness data .csv')
# copying the data to another variable
dd = datadental.copy()

# %% [markdown]
# ## Step 2: Overview of the data

# %%
dd.head()
# Out:
#    Dentist  Method  Alloy  Temp  Response
# 0        1       1      1  1500       813
# 1        1       1      1  1600       792
# 2        1       1      1  1700       792
# 3        1       1      2  1500       907
# 4        1       1      2  1600       792

# %% [markdown]
# The dataset reflects the response of interests from various patients with respect to the hardness of metal implants in dental cavities. The hardness depends on multiple factors such as implant methods, alloys used, dentist's favor and the metal's temparature. However the metal's temperature is just an observation.

# %%
dd.describe() #statistical summary of the data
# Out:
#          Dentist     Method      Alloy         Temp     Response
# count  90.000000  90.000000  90.000000    90.000000    90.000000
# mean    3.000000   2.000000   1.500000  1600.000000   741.777778
# std     1.422136   0.821071   0.502801    82.107083   145.767845
# min     1.000000   1.000000   1.000000  1500.000000   289.000000
# 25%     2.000000   1.000000   1.000000  1500.000000   698.000000
# 50%     3.000000   2.000000   1.500000  1600.000000   767.000000
# 75%     4.000000   3.000000   2.000000  1700.000000   824.000000
# max     5.000000   3.000000   2.000000  1700.000000  1115.000000

# %% [markdown]
# * The dataset produces the response of interests from **90 patients** with dental cavities regarding the hardness level of metal implants
# * There are a maximum of **5 dentists** following **3 methods of treatment** using either of the **2 alloys** as metal to implant at the dental cavity
# * It is also seen that the method, alloy and dentist are taken as numbers whereas they are labels, they are not values but they are categories.

# %%
dd.info() # information about the data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Dentist   90 non-null     int64
#  1   Method    90 non-null     int64
#  2   Alloy     90 non-null     int64
#  3   Temp      90 non-null     int64
#  4   Response  90 non-null     int64
# dtypes: int64(5)
# memory usage: 3.6 KB

# %%
# Dentist, Method and Alloy are categories , so we change them to categorical variables
dd.Dentist=pd.Categorical(dd.Dentist)
dd.Dentist.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0     1
# 1     1
# 2     1
# 3     1
# 4     1
#      ..
# 85    5
# 86    5
# 87    5
# 88    5
# 89    5
# Name: Dentist, Length: 90, dtype: category
# Categories (5, int64): [1, 2, 3, 4, 5]>

# %%
dd.Method=pd.Categorical(dd.Method)
dd.Method.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0     1
# 1     1
# 2     1
# 3     1
# 4     1
#      ..
# 85    3
# 86    3
# 87    3
# 88    3
# 89    3
# Name: Method, Length: 90, dtype: category
# Categories (3, int64): [1, 2, 3]>

# %%
dd.Alloy=pd.Categorical(dd.Alloy)
dd.Alloy.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0     1
# 1     1
# 2     1
# 3     2
# 4     2
#      ..
# 85    1
# 86    1
# 87    2
# 88    2
# 89    2
# Name: Alloy, Length: 90, dtype: category
# Categories (2, int64): [1, 2]>

# %% [markdown]
# ## 4.1	How does the hardness of implants vary depending on dentists?

# %% [markdown]
# **RUBRIC** - State the null and alternate hypotheses - Check the assumptions of the hypothesis test. - Conduct the hypothesis test and compute the p-value - Write down conclusions from the test results - In case the implant hardness differs, identify for which pairs it differs Note: 1. Both types of alloys cannot be considered together. You must conduct the analysis separately for the two types of alloys. 2. Even if the assumptions of the test fail, kindly proceed with the test."

# %% [markdown]
# ## **Exploratory Data Analysis**

# %% [markdown]
# #### **Value counts of different types of dentists**

# %%
dd.Dentist.value_counts()
# Out:
# Dentist
# 1    18
# 2    18
# 3    18
# 4    18
# 5    18
# Name: count, dtype: int64

# %% [markdown]
# * Based on the information of the data, there are Five different Dentists: 1, 2, 3, 4 and 5
# * In the sample of 90 people, each 18 were treated of every one of the five dentists

# %% [markdown]
# #### **Value counts of different types of alloys**

# %%
dd.Alloy.value_counts()
# Out:
# Alloy
# 1    45
# 2    45
# Name: count, dtype: int64

# %% [markdown]
# * Based on the information of the data, there are 2 different alloys used to treat dental cavities: 1, and 2
# * In the sample of 90 people, each 45 were treated with either one of the alloys

# %% [markdown]
# ### **Visualize data**

# %%
# visual analysis of the responses for the five different dentists
sns.boxplot(x="Dentist", y="Response", data = datadental)
plt.show()

# %%
# Visual analysis of the responses for the five different dentists with hue based on 'Alloy' column
sns.boxplot(x="Dentist", y="Response", hue="Alloy", data=dd)
plt.show()

# %% [markdown]
# *	The distribution of responses seem to differ among 2 different types of alloys
# *	The response with alloy 2 treatment is high compared to the response with alloy1
# *	The median value of responses with alloy 2 looks similar with dentist 1, 2 and 4,5
# *	The difference is observed in responses among the dentists. To determine this we will test the differences using the statistical tests

# %% [markdown]
# ### **Creating two separate dataframes based on alloys**

# %%
ddalloy1=pd.DataFrame(dd)
ddalloy1=ddalloy1[ddalloy1['Alloy']==1]
ddalloy2=pd.DataFrame(dd)
ddalloy2=ddalloy2[ddalloy2['Alloy']==2]

# %% [markdown]
# #### **STEP 1: State the null and alternate hypotheses**
# Given that two different alloys say “Alloy-1” and “Alloy-2” are used by 5 different dentists to treat dental cavities through implants, the dental implant hardness can be hypothesized for both the alloys as follows:

# %% [markdown]
# The null and alternative hypotheses can be formulated as:
#
# > $H_0$ : The mean responses with respect to each **dentist** is equal. <br>
# > $H_a$ : At least one of the mean responses with respect to the five **dentist** is different.

# %% [markdown]
# #### **STEP 2: Select Appropriate test**

# %% [markdown]
# **Check the assumptions of the hypothesis test**

# %% [markdown]
# This is a problem, concerning five population means.  ANOVA is an appropriate test here provided normality and equality of variance assumptions are verified.
#
# **ANOVA test**
#
# In an ANOVA test, we compare the means from several populations to test if there is any significance difference between them. The results from an ANOVA test are most reliable when the assumptions of normality and equality of variances are satisfied.
#
# * For testing of normality, Shapiro-Wilk’s test is applied to the response variable.
#
# * For equality of variance, Levene test is applied to the response variable.

# %% [markdown]
# **Shapiro-Wilk’s test**
#
# We will test the null hypothesis
#
# >$H_0:$ The responses follow a normal distribution
#
# against the alternative hypothesis
#
# >$H_a:$ The responses do not not follow a normal distribution

# %%
# Assumption 1: Normality - Dataframe - ddalloy1
# import the required function
from scipy import stats
# Use the shapiro function for the scipy.stats library for this test
# find the p-value
w, p_value = stats.shapiro(ddalloy1['Response']) 
print('The p-value is', p_value)
# Out:
# The p-value is 1.1945308699072215e-05

# %% [markdown]
# Since p-value of the test is less than the 5% significance level, we reject the null hypothesis that the response follows the normal distribution.

# %%
# Assumption 1: Normality - Dataframe - ddalloy2
# import the required function
from scipy import stats
# Use the shapiro function for the scipy.stats library for this test
# find the p-value
w, p_value = stats.shapiro(ddalloy2['Response']) 
print('The p-value is', p_value)
# Out:
# The p-value is 0.00040293129942514585

# %% [markdown]
# Since p-value of the test is less than the 5% significance level, we reject the null hypothesis that the response follows the normal distribution.

# %% [markdown]
# **Levene’s test**
#
# We will test the null hypothesis
#
# >$H_0$: All the population variances are equal
#
# against the alternative hypothesis
#
# >$H_a$: At least one variance is different from the rest

# %%
#Assumption 2: Homogeneity of Variance -Dataframe - ddalloy1
# use levene function from scipy.stats library for this test

# find the p-value
statistic, p_value = stats.levene(ddalloy1[ddalloy1['Dentist']=='1']['Response'],
                            ddalloy1[ddalloy1['Dentist']=='2']['Response'],
                            ddalloy1[ddalloy1['Dentist']=='3']['Response'], 
                            ddalloy1[ddalloy1['Dentist']=='4']['Response'],
                            ddalloy1[ddalloy1['Dentist']=='5']['Response'])
print('The p-value is', p_value)
# Out:
# The p-value is nan
# C:\Users\jemip\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Users\jemip\anaconda3\Lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)

# %%
#Assumption 2: Homogeneity of Variance -Dataframe - ddalloy2
# use levene function from scipy.stats library for this test

# find the p-value
statistic, p_value = stats.levene(ddalloy2[ddalloy2['Dentist']=='1']['Response'],
                            ddalloy2[ddalloy2['Dentist']=='2']['Response'],
                            ddalloy2[ddalloy2['Dentist']=='3']['Response'], 
                            ddalloy2[ddalloy2['Dentist']=='4']['Response'],
                            ddalloy2[ddalloy2['Dentist']=='5']['Response'])
print('The p-value is', p_value)
# Out:
# The p-value is nan
# C:\Users\jemip\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Users\jemip\anaconda3\Lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)

# %% [markdown]
# **The test for ANOVA fails for two different alloys**
# * The response does not follow normal distribution
# * All the population variances are not equal
#
# **We proceed with the test by designing the formula and using the Ordinary Least Squares algorithm**

# %%
# Analysis on overall data frame
formula = 'Response ~ C(Dentist)' #'+' means 'and' meaning taken together
model = ols(formula, dd).fit() # OLS - Ordinary Least Squares
aov_table = anova_lm(model)
print(aov_table)
#Mean square of factor/ mean squ of residual (F)
# Out:
#               df        sum_sq       mean_sq         F    PR(>F)
# C(Dentist)   4.0  1.577946e+05  39448.638889  1.934537  0.112066
# Residual    85.0  1.733301e+06  20391.776471       NaN       NaN

# %% [markdown]
# **Considering two alloys together**
#
# **The p-value is 0.112066**
#
# * Since p-value of the test is greater than the 5% significance level, we fail to reject the null hypothesis that mean response of five different dentists are same.

# %%
sns.pointplot(x='Dentist', y='Response', data=dd, hue='Alloy', ci=None)
plt.show();
# Out:
# C:\Users\jemip\AppData\Local\Temp\ipykernel_11896\2052203691.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.pointplot(x='Dentist', y='Response', data=dd, hue='Alloy', ci=None)

# %% [markdown]
# #### **STEP 3: Analysis of variation in hardness of implants depending on DENTISTS while using ALLOY-1**

# %%
# Analysis based on alloy1
formula = 'Response ~ C(Dentist)' #'+' means 'and' meaning taken together
model = ols(formula, ddalloy1).fit() # OLS - Ordinary Least Squares
aov_table = anova_lm(model)
print(aov_table)
#Mean square of factor/ mean squ of residual (F)
# Out:
#               df         sum_sq       mean_sq         F    PR(>F)
# C(Dentist)   4.0  106683.688889  26670.922222  1.977112  0.116567
# Residual    40.0  539593.555556  13489.838889       NaN       NaN

# %% [markdown]
# **Considering the hardness implant response with respect to ALLOY-1**
#
# **The p-value is 0.116567**
#
# * Since p-value of the test is greater than the 5% significance level, we fail to reject the null hypothesis that mean implant hardness response for five different dentists are same while treating the dental cavities with alloy-1.

# %% [markdown]
# #### **STEP 4: Analysis of variation in hardness of implants depending on DENTISTS while using ALLOY-2**

# %%
# Analysis based on alloy2
formula = 'Response ~ C(Dentist)' #'+' means 'and' meaning taken together
model = ols(formula, ddalloy2).fit() # OLS - Ordinary Least Squares
aov_table = anova_lm(model)
print(aov_table)
#Mean square of factor/ mean squ of residual (F)
# Out:
#               df        sum_sq       mean_sq         F    PR(>F)
# C(Dentist)   4.0  5.679791e+04  14199.477778  0.524835  0.718031
# Residual    40.0  1.082205e+06  27055.122222       NaN       NaN

# %% [markdown]
# **Considering the hardness implant response with respect to ALLOY-2**
#
# **The p-value is 0.718031**
#
# * Since p-value of the test is greater than the 5% significance level, we fail to reject the null hypothesis that mean implant hardness response for five different dentists are same while treating the dental cavities with alloy-2.

# %% [markdown]
# ## **Thus the hardness of implants does not vary with dentists irrespective of the alloys used to treat the dental cavities**

# %% [markdown]
# ## 4.2	How does the hardness of implants vary depending on methods?

# %% [markdown]
# **RUBRIC**-State the null and alternate hypotheses - Check the assumptions of the hypothesis test. - Conduct the hypothesis test and compute the p-value - Write down conclusions from the test results - In case the implant hardness differs, identify for which pairs it differs Note: 1. Both types of alloys cannot be considered together. You must conduct the analysis separately for the two types of alloys. 2. Even if the assumptions of the test fail, kindly proceed with the test."

# %% [markdown]
# ## **Exploratory Data Analysis**

# %% [markdown]
# #### **Value counts of different types of methods**

# %%
dd.Method.value_counts()
# Out:
# Method
# 1    30
# 2    30
# 3    30
# Name: count, dtype: int64

# %% [markdown]
# * Based on the information of the data, there are Three different Methods: 1, 2, and 3
# * In the sample of 90 people, each 30 were treated with any one of the three methods

# %%
dd.Alloy.value_counts()
# Out:
# Alloy
# 1    45
# 2    45
# Name: count, dtype: int64

# %% [markdown]
# *	Based on the information of the data, there are 2 different alloys used to treat dental cavities: 1, and 2
# *	In the sample of 90 people, each 45 were treated with either one of the alloys

# %% [markdown]
# ### **Visualize data**

# %%
# visual analysis of the responses for the three different methods
sns.boxplot(x="Method", y="Response", data = dd)
plt.show()

# %%
# Visual analysis of the responses for the three different methods with hue based on 'Alloy' column
sns.boxplot(x="Method", y="Response", hue="Alloy", data=dd)
plt.show()

# %% [markdown]
# *	The distribution of responses seem to differ among 2 different types of alloys
# *	The response with alloy 2 treatment is high compared to the response with alloy1in methods 1 and 2, whereas with method 3 the response is similar
# *	The median value of responses with alloy 2 looks similar with method 3
# *	The difference is observed in responses among the methods. To determine this we will test the differences using the statistical tests

# %% [markdown]
# ### **Creating two separate dataframes based on alloys**

# %%
ddalloy1=pd.DataFrame(dd)
ddalloy1=ddalloy1[ddalloy1['Alloy']==1]
ddalloy2=pd.DataFrame(dd)
ddalloy2=ddalloy2[ddalloy2['Alloy']==2]

# %% [markdown]
# #### **STEP 1: State the null and alternate hypotheses**
# Given that two different alloys say “Alloy-1” and “Alloy-2” are used by 3 different methods  to treat dental cavities through implants, the dental implant hardness can be hypothesized for both the alloys as follows:

# %% [markdown]
# The null and alternative hypotheses can be formulated as:
#
# > $H_0$ : The mean responses with respect to each **method** is equal. <br>
# > $H_a$ : At least one of the mean responses with respect to the **three methods is different**.

# %% [markdown]
# #### **STEP 2: Select Appropriate test**

# %% [markdown]
# **Check the assumptions of the hypothesis test**

# %% [markdown]
# This is a problem, concerning three population means.  ANOVA is an appropriate test here provided normality and equality of variance assumptions are verified.
#
# **ANOVA test**
#
# In an ANOVA test, we compare the means from several populations to test if there is any significance difference between them. The results from an ANOVA test are most reliable when the assumptions of normality and equality of variances are satisfied.
#
# * For testing of normality, Shapiro-Wilk’s test is applied to the response variable.
#
# * For equality of variance, Levene test is applied to the response variable.

# %% [markdown]
# **Shapiro-Wilk’s test**
#
# We will test the null hypothesis
#
# >$H_0:$ The responses follow a normal distribution
#
# against the alternative hypothesis
#
# >$H_a:$ The responses do not not follow a normal distribution

# %%
# Assumption 1: Normality - Dataframe - ddalloy1
# import the required function
from scipy import stats
# Use the shapiro function for the scipy.stats library for this test
# find the p-value
w, p_value = stats.shapiro(ddalloy1['Response']) 
print('The p-value is', p_value)
# Out:
# The p-value is 1.1945308699072215e-05

# %% [markdown]
# Since p-value of the test is less than the 5% significance level, we reject the null hypothesis that the response follows the normal distribution.

# %%
# Assumption 1: Normality - Dataframe - ddalloy2
# import the required function
from scipy import stats
# Use the shapiro function for the scipy.stats library for this test
# find the p-value
w, p_value = stats.shapiro(ddalloy2['Response']) 
print('The p-value is', p_value)
# Out:
# The p-value is 0.00040293129942514585

# %% [markdown]
# Since p-value of the test is less than the 5% significance level, we reject the null hypothesis that the response follows the normal distribution.

# %% [markdown]
# **Levene’s test**
#
# We will test the null hypothesis
#
# >$H_0$: All the population variances are equal
#
# against the alternative hypothesis
#
# >$H_a$: At least one variance is different from the rest

# %%
#Assumption 2: Homogeneity of Variance -Dataframe - ddalloy1
# use levene function from scipy.stats library for this test

# find the p-value
statistic, p_value = stats.levene(ddalloy1[ddalloy1['Method']=='1']['Response'],
                            ddalloy1[ddalloy1['Method']=='2']['Response'],
                            ddalloy1[ddalloy1['Method']=='3']['Response']) 
                            
print('The p-value is', p_value)
# Out:
# The p-value is nan
# C:\Users\jemip\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Users\jemip\anaconda3\Lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)

# %%
#Assumption 2: Homogeneity of Variance -Dataframe - ddalloy1
# use levene function from scipy.stats library for this test

# find the p-value
statistic, p_value = stats.levene(ddalloy2[ddalloy2['Method']=='1']['Response'],
                            ddalloy2[ddalloy2['Method']=='2']['Response'],
                            ddalloy2[ddalloy2['Method']=='3']['Response']) 
                            
print('The p-value is', p_value)
# Out:
# The p-value is nan
# C:\Users\jemip\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Users\jemip\anaconda3\Lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)

# %% [markdown]
# **The test for ANOVA fails for two different alloys**
# * The response does not follow normal distribution
# * All the population variances are not equal
#
# **We proceed with the test by designing the formula and using the Ordinary Least Squares algorithm**

# %%
# Analysis on overall data frame
formula = 'Response ~ C(Method)' #'+' means 'and' meaning taken together
model = ols(formula, dd).fit() # OLS - Ordinary Least Squares
aov_table = anova_lm(model)
print(aov_table)
#Mean square of factor/ mean squ of residual (F)
# Out:
#              df        sum_sq        mean_sq         F        PR(>F)
# C(Method)   2.0  5.934275e+05  296713.744444  19.89268  7.683892e-08
# Residual   87.0  1.297668e+06   14915.724904       NaN           NaN

# %% [markdown]
# **Considering two alloys together**
#
# **The p-value is 7.683892e-08**
#
# * Since p-value of the test is less than the 5% significance level, we reject the null hypothesis that mean response of three different methods are same.

# %%
sns.pointplot(x='Method', y='Response', data=dd, hue='Alloy', ci=None)
plt.show();
# Out:
# C:\Users\jemip\AppData\Local\Temp\ipykernel_11896\4276499488.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.pointplot(x='Method', y='Response', data=dd, hue='Alloy', ci=None)

# %% [markdown]
# #### **STEP 3: Analysis of variation in hardness of implants depending on METHODS while using ALLOY-1**

# %%
# Analysis based on alloy1
formula = 'Response ~ C(Method)' #'+' means 'and' meaning taken together
model = ols(formula, ddalloy1).fit() # OLS - Ordinary Least Squares
aov_table = anova_lm(model)
print(aov_table)
#Mean square of factor/ mean squ of residual (F)
# Out:
#              df         sum_sq       mean_sq         F    PR(>F)
# C(Method)   2.0  148472.177778  74236.088889  6.263327  0.004163
# Residual   42.0  497805.066667  11852.501587       NaN       NaN

# %% [markdown]
# **Considering the hardness implant response with respect to ALLOY-1**
#
# **The p-value is 0.004163**
#
# * Since p-value of the test is less than the 5% significance level, we reject the null hypothesis that mean implant hardness response for three different methods are same while treating the dental cavities with alloy-1.

# %% [markdown]
# #### **STEP 4: Analysis of variation in hardness of implants depending on METHODS while using ALLOY-2**

# %%
# Analysis based on alloy1
formula = 'Response ~ C(Method)' #'+' means 'and' meaning taken together
model = ols(formula, ddalloy2).fit() # OLS - Ordinary Least Squares
aov_table = anova_lm(model)
print(aov_table)
#Mean square of factor/ mean squ of residual (F)
# Out:
#              df    sum_sq        mean_sq        F    PR(>F)
# C(Method)   2.0  499640.4  249820.200000  16.4108  0.000005
# Residual   42.0  639362.4   15222.914286      NaN       NaN

# %% [markdown]
# **Considering the hardness implant response with respect to ALLOY-2**
#
# **The p-value is 0.000005**
#
# * Since p-value of the test is less than the 5% significance level, we reject the null hypothesis that mean implant hardness response for three different methods are same while treating the dental cavities with alloy-2.

# %% [markdown]
# ## **Thus the hardness of implants vary with methods irrespective of the alloys used to treat the dental cavities**

# %% [markdown]
# ####  **STEP 5: In case the implant hardness differs, identifying for which pairs it differs**

# %% [markdown]
# ### Multiple Comparison test (Tukey HSD)

# %% [markdown]
# In order to identify for which method mean response is different from other groups, the null hypothesis is
#
#   > $𝐻_0: 𝜇_{method1}=𝜇_{method2} \text{ and } 𝜇_{method1}=𝜇_{method3} \text{ and } 𝜇_{method2}=𝜇_{method3}$
#
# against the alternative hypothesis
#
#  > $𝐻_a: 𝜇_{method1}\neq𝜇_{method2} \text{ or } 𝜇_{method1}\neq𝜇_{method3} \text{ or } 𝜇_{method2}\neq𝜇_{method3}$

# %%
#import the required function
from statsmodels.stats.multicomp import pairwise_tukeyhsd

# perform multiple pairwise comparison (Tukey HSD)
m_comp = pairwise_tukeyhsd(endog = ddalloy1['Response'], groups = ddalloy1['Method'], alpha = 0.05)
print(m_comp)
# Out:
#   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2  meandiff p-adj    lower    upper   reject
# --------------------------------------------------------
#      1      2   -6.1333  0.987  -102.714  90.4473  False
#      1      3    -124.8 0.0085 -221.3807 -28.2193   True
#      2      3 -118.6667 0.0128 -215.2473  -22.086   True
# --------------------------------------------------------

# %% [markdown]
# While using **ALLOY-1** for treating the dental cavities
# * The response of hardness of dental implants **differs between method 1 and method 3**
# * The response of hardness of dental implants also **differs between method 2 and method 3**
# * The response of hardness of dental implants is not so different between method 1 and method 2

# %%
#import the required function
from statsmodels.stats.multicomp import pairwise_tukeyhsd

# perform multiple pairwise comparison (Tukey HSD)
m_comp = pairwise_tukeyhsd(endog = ddalloy2['Response'], groups = ddalloy2['Method'], alpha = 0.05)
print(m_comp)
# Out:
#   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj    lower     upper   reject
# --------------------------------------------------------
#      1      2     27.0 0.8212  -82.4546  136.4546  False
#      1      3   -208.8 0.0001 -318.2546  -99.3454   True
#      2      3   -235.8    0.0 -345.2546 -126.3454   True
# --------------------------------------------------------

# %% [markdown]
# While using **ALLOY-2** for treating the dental cavities
# * The response of hardness of dental implants **differs between method 1 and method 3**
# * The response of hardness of dental implants also **differs between method 2 and method 3**
# * The response of hardness of dental implants is not so different between method 1 and method 2

# %% [markdown]
# ## **Thus the hardness of implants with method3 is different from method 1 and method2 irrespective of using any of the alloys**

# %% [markdown]
# ## 4.3	What is the interaction effect between the dentist and method on the hardness of dental implants for each type of alloy?

# %% [markdown]
# **RUBRIC** - Create Interaction Plot - Inferences from the plot Note: Both types of alloys cannot be considered together. You must conduct the analysis separately for the two types of alloys."

# %% [markdown]
# #### **STEP 1: State the null and alternate hypotheses**
# Given that two different alloys say “Alloy-1” and “Alloy-2” are used by 5 different dentists with 3 different methods  to treat dental cavities through implants, the interaction effect between the dentists and methods on the hardness of dental implants can be hypothesized for both the alloys as follows:

# %% [markdown]
# The null and alternative hypotheses can be formulated as:
#
# > $H_0$ : There is **no interaction effect between the dentist and the method**
# >
# > $H_a$ : There is an **interaction effect between the dentist and the method**

# %% [markdown]
# #### **STEP 2: Analysis of interaction effect between dentist and the method while using ALLOY-1**

# %%
#Analysis of interaction effect between dentist and the method while using ALLOY-1
formula = 'Response ~ C(Dentist) + C(Method) + C(Dentist):C(Method)'
model = ols(formula, ddalloy1).fit()
aov_table = anova_lm(model)
print(aov_table)
# Out:
#                         df         sum_sq       mean_sq          F    PR(>F)
# C(Dentist)             4.0  106683.688889  26670.922222   3.899638  0.011484
# C(Method)              2.0  148472.177778  74236.088889  10.854287  0.000284
# C(Dentist):C(Method)   8.0  185941.377778  23242.672222   3.398383  0.006793
# Residual              30.0  205180.000000   6839.333333        NaN       NaN

# %% [markdown]
# **Considering the interaction effect between dentist and the method with respect to ALLOY-1**
#
# **The p-value is 0.006793**
#
# * Since p-value of the test is less than the 5% significance level, we reject the null hypothesis
# * So there is an interaction effect between the dentist and the methods used to treat the dental cavities while treating with alloy-1

# %%
sns.pointplot(x='Dentist', y='Response', data=ddalloy1, hue='Method', ci=None)
plt.show();
# Out:
# C:\Users\jemip\AppData\Local\Temp\ipykernel_11896\2424557839.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.pointplot(x='Dentist', y='Response', data=ddalloy1, hue='Method', ci=None)

# %% [markdown]
# #### **STEP 3: Analysis of interaction effect between dentist and the method while using ALLOY-2**

# %%
#Analysis of interaction effect between dentist and the method while using ALLOY-2
formula = 'Response ~ C(Dentist) + C(Method) + C(Dentist):C(Method)'
model = ols(formula, ddalloy2).fit()
aov_table = anova_lm(model)
print(aov_table)
# Out:
#                         df         sum_sq        mean_sq          F    PR(>F)
# C(Dentist)             4.0   56797.911111   14199.477778   1.106152  0.371833
# C(Method)              2.0  499640.400000  249820.200000  19.461218  0.000004
# C(Dentist):C(Method)   8.0  197459.822222   24682.477778   1.922787  0.093234
# Residual              30.0  385104.666667   12836.822222        NaN       NaN

# %% [markdown]
# **Considering the interaction effect between dentist and the method with respect to ALLOY-2**
#
# **The p-value is 0.093234**
#
# * Since p-value of the test is greater than the 5% significance level, we cannot reject the null hypothesis
# * So there is no interaction effect between the dentist and the methods used to treat the dental cavities while treating with alloy-2

# %%
sns.pointplot(x='Dentist', y='Response', data=ddalloy2, hue='Method', ci=None)
plt.show();
# Out:
# C:\Users\jemip\AppData\Local\Temp\ipykernel_11896\439858042.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.pointplot(x='Dentist', y='Response', data=ddalloy2, hue='Method', ci=None)

# %% [markdown]
# #### **STEP 4: Create Interaction plot**

# %% [markdown]
# The analysis of the effect of both the `Dentist` and `Method` on the `Response` variable is done using interaction plots

# %%
### ALLOY-1
from statsmodels.graphics.factorplots import interaction_plot
interaction_plot(np.array(ddalloy1['Dentist']),np.array(ddalloy1['Method']),np.array(ddalloy1['Response']),markers=['D','^','o'])

# %% [markdown]
# ## **There is some sort of an interaction between the dentist and the methods used to treat the dental cavities while treating with alloy-1**

# %%
### ALLOY-2
from statsmodels.graphics.factorplots import interaction_plot
interaction_plot(np.array(ddalloy2['Dentist']),np.array(ddalloy2['Method']),np.array(ddalloy2['Response']),markers=['D','^','o'])

# %% [markdown]
# ## **There is no interaction between the dentist and the methods used to treat the dental cavities while treating with alloy-2**

# %% [markdown]
# ## 4.4	How does the hardness of implants vary depending on dentists and methods together?

# %% [markdown]
# **RUBRIC** - State the null and alternate hypotheses - Check the assumptions of the hypothesis test. - Conduct the hypothesis test and compute the p-value - Write down conclusions from the test results - Identify which dentists and methods combinations are different, and which interaction levels are different. Note: 1. Both types of alloys cannot be considered together. You must conduct the analysis separately for the two types of alloys. 2. Even if the assumptions of the test fail, kindly proceed with the test.

# %% [markdown]
# ## **Exploratory Data Analysis**

# %%
dd.Dentist.value_counts()
# Out:
# Dentist
# 1    18
# 2    18
# 3    18
# 4    18
# 5    18
# Name: count, dtype: int64

# %% [markdown]
# * Based on the information of the data, there are Five different Dentists: 1, 2, 3, 4 and 5
# * In the sample of 90 people, each 18 were treated of every one of the five dentists

# %%
# complete the code to plot the countplot
sns.countplot(data=dd,x='Dentist',hue='Alloy')
plt.show()

# %%
dd.Method.value_counts()
# Out:
# Method
# 1    30
# 2    30
# 3    30
# Name: count, dtype: int64

# %% [markdown]
# * Based on the information of the data, there are Three different Methods: 1, 2, and 3
# * In the sample of 90 people, each 30 were treated with any one of the three methods

# %%
# complete the code to plot the countplot
sns.countplot(data=dd,x='Method',hue='Alloy')
plt.show()

# %%
dd.Alloy.value_counts()
# Out:
# Alloy
# 1    45
# 2    45
# Name: count, dtype: int64

# %%
# complete the code to plot the countplot
sns.countplot(data=dd,x='Alloy',hue='Dentist')
plt.show()

# %%
# complete the code to plot the countplot
sns.countplot(data=dd,x='Alloy',hue='Method')
plt.show()

# %% [markdown]
# ### Bivariate Analysis

# %% [markdown]
# #### Dentist vs Response (with alloy1)

# %%
plt.figure(figsize=(10,6))
sns.boxplot(data=ddalloy1,x='Dentist',y='Response', hue='Method')
plt.show()

# %% [markdown]
# #### Dentist vs Response (with alloy2)

# %%
plt.figure(figsize=(10,6))
sns.boxplot(data=ddalloy2,x='Dentist',y='Response', hue='Method')
plt.show()

# %% [markdown]
# #### Method vs Response (with alloy1)

# %%
plt.figure(figsize=(10,6))
sns.boxplot(data=ddalloy1,x='Method',y='Response', hue='Dentist')
plt.show()

# %% [markdown]
# #### Method vs Response (with alloy2)

# %%
plt.figure(figsize=(10,6))
sns.boxplot(data=ddalloy2,x='Method',y='Response', hue='Dentist')
plt.show()

# %% [markdown]
# #### **STEP 1: State the null and alternate hypotheses**
# Given that two different alloys say “Alloy-1” and “Alloy-2” are used by 5 different dentists implementing 3 different methods  to treat dental cavities through implants, the dental implant hardness can be hypothesized for both the alloys as follows:

# %% [markdown]
# The null and alternative hypotheses can be formulated as:
#
# > $H_0$ : The mean responses with respect to each **dentist along with the respective method** is equal. <br>
# > $H_a$ : At least one of the mean responses with respect to the **5 dentists and 3 methods is different**.

# %% [markdown]
# #### **STEP 2: Select Appropriate test**

# %% [markdown]
# **Check the assumptions of the hypothesis test**

# %% [markdown]
# This is a problem, concerning three population means.  ANOVA is an appropriate test here provided normality and equality of variance assumptions are verified.
#
# **ANOVA test**
#
# In an ANOVA test, we compare the means from several populations to test if there is any significance difference between them. The results from an ANOVA test are most reliable when the assumptions of normality and equality of variances are satisfied.
#
# * For testing of normality, Shapiro-Wilk’s test is applied to the response variable.
#
# * For equality of variance, Levene test is applied to the response variable.

# %% [markdown]
# **Shapiro-Wilk’s test**
#
# We will test the null hypothesis
#
# >$H_0:$ The responses follow a normal distribution
#
# against the alternative hypothesis
#
# >$H_a:$ The responses do not not follow a normal distribution

# %%
# Assumption 1: Normality - Dataframe - ddalloy1
# import the required function
from scipy import stats
# Use the shapiro function for the scipy.stats library for this test
# find the p-value
w, p_value = stats.shapiro(ddalloy1['Response']) 
print('The p-value is', p_value)
# Out:
# The p-value is 1.1945308699072215e-05

# %% [markdown]
# Since p-value of the test is less than the 5% significance level, we reject the null hypothesis that the response follows the normal distribution.

# %%
# Assumption 1: Normality - Dataframe - ddalloy2
# import the required function
from scipy import stats
# Use the shapiro function for the scipy.stats library for this test
# find the p-value
w, p_value = stats.shapiro(ddalloy2['Response']) 
print('The p-value is', p_value)
# Out:
# The p-value is 0.00040293129942514585

# %% [markdown]
# Since p-value of the test is less than the 5% significance level, we reject the null hypothesis that the response follows the normal distribution.

# %% [markdown]
# **Levene’s test**
#
# We will test the null hypothesis
#
# >$H_0$: All the population variances are equal
#
# against the alternative hypothesis
#
# >$H_a$: At least one variance is different from the rest

# %%
#Assumption 2: Homogeneity of Variance -Dataframe - ddalloy1
# use levene function from scipy.stats library for this test

# find the p-value
statistic, p_value = stats.levene(ddalloy1[ddalloy1['Method']=='1']['Response'],ddalloy1[ddalloy1['Dentist']=='1']['Response'],
                                  ddalloy1[ddalloy1['Method']=='1']['Response'],ddalloy1[ddalloy1['Dentist']=='2']['Response'],
                                  ddalloy1[ddalloy1['Method']=='1']['Response'],ddalloy1[ddalloy1['Dentist']=='3']['Response'],
                                  ddalloy1[ddalloy1['Method']=='1']['Response'],ddalloy1[ddalloy1['Dentist']=='4']['Response'],
                                  ddalloy1[ddalloy1['Method']=='1']['Response'],ddalloy1[ddalloy1['Dentist']=='5']['Response'],
                                  ddalloy1[ddalloy1['Method']=='2']['Response'],ddalloy1[ddalloy1['Dentist']=='1']['Response'],
                                  ddalloy1[ddalloy1['Method']=='2']['Response'],ddalloy1[ddalloy1['Dentist']=='2']['Response'],
                                  ddalloy1[ddalloy1['Method']=='2']['Response'],ddalloy1[ddalloy1['Dentist']=='3']['Response'],
                                  ddalloy1[ddalloy1['Method']=='2']['Response'],ddalloy1[ddalloy1['Dentist']=='4']['Response'],
                                  ddalloy1[ddalloy1['Method']=='2']['Response'],ddalloy1[ddalloy1['Dentist']=='5']['Response'],
                                  ddalloy1[ddalloy1['Method']=='3']['Response'],ddalloy1[ddalloy1['Dentist']=='1']['Response'],
                                  ddalloy1[ddalloy1['Method']=='3']['Response'],ddalloy1[ddalloy1['Dentist']=='2']['Response'],
                                  ddalloy1[ddalloy1['Method']=='3']['Response'],ddalloy1[ddalloy1['Dentist']=='3']['Response'],
                                  ddalloy1[ddalloy1['Method']=='3']['Response'],ddalloy1[ddalloy1['Dentist']=='4']['Response'],
                                  ddalloy1[ddalloy1['Method']=='3']['Response'],ddalloy1[ddalloy1['Dentist']=='5']['Response']) 
                            
print('The p-value is', p_value)
# Out:
# The p-value is nan
# C:\Users\jemip\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Users\jemip\anaconda3\Lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)

# %%
#Assumption 2: Homogeneity of Variance -Dataframe - ddalloy2
# use levene function from scipy.stats library for this test

# find the p-value
statistic, p_value = stats.levene(ddalloy2[ddalloy2['Method']=='1']['Response'],ddalloy2[ddalloy2['Dentist']=='1']['Response'],
                                  ddalloy2[ddalloy2['Method']=='1']['Response'],ddalloy2[ddalloy2['Dentist']=='2']['Response'],
                                  ddalloy2[ddalloy2['Method']=='1']['Response'],ddalloy2[ddalloy2['Dentist']=='3']['Response'],
                                  ddalloy2[ddalloy2['Method']=='1']['Response'],ddalloy2[ddalloy2['Dentist']=='4']['Response'],
                                  ddalloy2[ddalloy2['Method']=='1']['Response'],ddalloy2[ddalloy2['Dentist']=='5']['Response'],
                                  ddalloy2[ddalloy2['Method']=='2']['Response'],ddalloy2[ddalloy2['Dentist']=='1']['Response'],
                                  ddalloy2[ddalloy2['Method']=='2']['Response'],ddalloy2[ddalloy2['Dentist']=='2']['Response'],
                                  ddalloy2[ddalloy2['Method']=='2']['Response'],ddalloy2[ddalloy2['Dentist']=='3']['Response'],
                                  ddalloy2[ddalloy2['Method']=='2']['Response'],ddalloy2[ddalloy2['Dentist']=='4']['Response'],
                                  ddalloy2[ddalloy2['Method']=='2']['Response'],ddalloy2[ddalloy2['Dentist']=='5']['Response'],
                                  ddalloy2[ddalloy2['Method']=='3']['Response'],ddalloy2[ddalloy2['Dentist']=='1']['Response'],
                                  ddalloy2[ddalloy2['Method']=='3']['Response'],ddalloy2[ddalloy2['Dentist']=='2']['Response'],
                                  ddalloy2[ddalloy2['Method']=='3']['Response'],ddalloy2[ddalloy2['Dentist']=='3']['Response'],
                                  ddalloy2[ddalloy2['Method']=='3']['Response'],ddalloy2[ddalloy2['Dentist']=='4']['Response'],
                                  ddalloy2[ddalloy2['Method']=='3']['Response'],ddalloy2[ddalloy2['Dentist']=='5']['Response']) 
                            
print('The p-value is', p_value)
# Out:
# The p-value is nan
# C:\Users\jemip\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Users\jemip\anaconda3\Lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)

# %% [markdown]
# #### **STEP 3: Analysis of variation in hardness of implants depending on dentists and methods together while using ALLOY-1**

# %%
#Analysis of variation in hardness of implants depending on dentists and methods together while using ALLOY-1
formula = 'Response ~ C(Dentist) + C(Method)'
model = ols(formula, ddalloy1).fit()
aov_table = anova_lm(model)
print(aov_table)
# Out:
#               df         sum_sq       mean_sq         F    PR(>F)
# C(Dentist)   4.0  106683.688889  26670.922222  2.591255  0.051875
# C(Method)    2.0  148472.177778  74236.088889  7.212522  0.002211
# Residual    38.0  391121.377778  10292.667836       NaN       NaN

# %% [markdown]
# **Considering the hardness implant response depending on dentists and methods together with respect to ALLOY-1**
#
# **The p-value is 0.051875 with respect to DENTIST**
#
# *	Since p-value of the test is greater than the 5% significance level, we fail to reject the null hypothesis that mean implant hardness response for five different dentists are same while treating the dental cavities with alloy-1.
# *	So there is **no significant variation in hardness of implants depending on dentists** while treating with alloy-1
#
# **The p-value is 0.002211 with respect to METHOD**
#
# *	Since p-value of the test is less than the 5% significance level, we reject the null hypothesis that mean implant hardness response for 3 different methods are same while treating the dental cavities with alloy-1.
# *	So there is **significant variation in hardness of implants depending on methods** while treating with alloy-1

# %% [markdown]
# #### **STEP 4: Analysis of variation in hardness of implants depending on dentists and methods together while using ALLOY-2**

# %%
#Analysis of variation in hardness of implants depending on dentists and methods together while using ALLOY-2
formula = 'Response ~ C(Dentist) + C(Method)'
model = ols(formula, ddalloy2).fit()
aov_table = anova_lm(model)
print(aov_table)
# Out:
#               df         sum_sq        mean_sq          F    PR(>F)
# C(Dentist)   4.0   56797.911111   14199.477778   0.926215  0.458933
# C(Method)    2.0  499640.400000  249820.200000  16.295479  0.000008
# Residual    38.0  582564.488889   15330.644444        NaN       NaN

# %% [markdown]
# **Considering the hardness implant response depending on dentists and methods together with respect to ALLOY-2**
#
# **The p-value is 0.458933 with respect to DENTIST**
#
#
# *	Since p-value of the test is greater than the 5% significance level, we fail to reject the null hypothesis that mean implant hardness response for five different dentists are same while treating the dental cavities with alloy-2.
# *	So there is **no significant variation in hardness of implants depending on dentists** while treating with alloy-2
#
# **The p-value is 0.000008 with respect to METHOD**
#
# *	Since p-value of the test is less than the 5% significance level, we reject the null hypothesis that mean implant hardness response for 3 different methods are same while treating the dental cavities with alloy-2.
# *	So there is **significant variation in hardness of implants depending on methods** while treating with alloy-2

# %% [markdown]
# ####  **STEP 5: Identify which dentists and methods combinations are different, and which interaction levels are different.**

# %% [markdown]
# ### Multiple Comparison test (Tukey HSD) - Dentist combinations

# %% [markdown]
# In order to identify for which method mean response is different from other groups, the null hypothesis is
#
#   > $𝐻_0: The mean response for any pair of dentist combinations is the same while treating with either of the alloys
#
# against the alternative hypothesis
#
#  > $𝐻_a: The mean response for at least one pair of dentist combinations is different while treating with either of the alloys

# %%
#import the required function
from statsmodels.stats.multicomp import pairwise_tukeyhsd

# perform multiple pairwise comparison (Tukey HSD)
m_comp = pairwise_tukeyhsd(endog = ddalloy1['Response'], groups = ddalloy1['Dentist'], alpha = 0.05)
print(m_comp)
# Out:
#   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2  meandiff p-adj    lower    upper   reject
# --------------------------------------------------------
#      1      2   11.3333 0.9996 -145.0423  167.709  False
#      1      3  -32.3333 0.9757  -188.709 124.0423  False
#      1      4  -68.7778 0.7189 -225.1535  87.5979  False
#      1      5 -122.2222 0.1889 -278.5979  34.1535  False
#      2      3  -43.6667 0.9298 -200.0423  112.709  False
#      2      4  -80.1111 0.5916 -236.4868  76.2646  False
#      2      5 -133.5556 0.1258 -289.9312  22.8201  False
#      3      4  -36.4444 0.9626 -192.8201 119.9312  False
#      3      5  -89.8889 0.4805 -246.2646  66.4868  False
#      4      5  -53.4444 0.8643 -209.8201 102.9312  False
# --------------------------------------------------------

# %% [markdown]
# #### **Thus the mean hardness of implants remains the same for any pair of dentist combinations while treating with alloy-1**

# %%
#import the required function
from statsmodels.stats.multicomp import pairwise_tukeyhsd

# perform multiple pairwise comparison (Tukey HSD)
m_comp = pairwise_tukeyhsd(endog = ddalloy2['Response'], groups = ddalloy2['Dentist'], alpha = 0.05)
print(m_comp)
# Out:
#   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj    lower    upper   reject
# -------------------------------------------------------
#      1      2  -4.1111    1.0 -225.5687 217.3465  False
#      1      3 -36.5556 0.9895 -258.0131  184.902  False
#      1      4    -70.0 0.8941 -291.4576 151.4576  False
#      1      5 -90.1111 0.7724 -311.5687 131.3465  False
#      2      3 -32.4444 0.9933  -253.902 189.0131  False
#      2      4 -65.8889 0.9132 -287.3465 155.5687  False
#      2      5    -86.0 0.8008 -307.4576 135.4576  False
#      3      4 -33.4444 0.9925  -254.902 188.0131  False
#      3      5 -53.5556 0.9574 -275.0131  167.902  False
#      4      5 -20.1111  0.999 -241.5687 201.3465  False
# -------------------------------------------------------

# %% [markdown]
# #### **Thus the mean hardness of implants remains the same for any pair of dentist combinations while treating with alloy-2**

# %%
# Multiple Comparison test (Tukey HSD) - Method combinations –(Alloy1 & Alloy2)
#import the required function
from statsmodels.stats.multicomp import pairwise_tukeyhsd

# perform multiple pairwise comparison (Tukey HSD)
m_comp = pairwise_tukeyhsd(endog = ddalloy1['Response'], groups = ddalloy1['Method'], alpha = 0.05)
print(m_comp)
# Out:
#   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2  meandiff p-adj    lower    upper   reject
# --------------------------------------------------------
#      1      2   -6.1333  0.987  -102.714  90.4473  False
#      1      3    -124.8 0.0085 -221.3807 -28.2193   True
#      2      3 -118.6667 0.0128 -215.2473  -22.086   True
# --------------------------------------------------------

# %%
# Multiple Comparison test (Tukey HSD) - Method combinations –(Alloy1 & Alloy2)
#import the required function
from statsmodels.stats.multicomp import pairwise_tukeyhsd

# perform multiple pairwise comparison (Tukey HSD)
m_comp = pairwise_tukeyhsd(endog = ddalloy2['Response'], groups = ddalloy2['Method'], alpha = 0.05)
print(m_comp)
# Out:
#   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj    lower     upper   reject
# --------------------------------------------------------
#      1      2     27.0 0.8212  -82.4546  136.4546  False
#      1      3   -208.8 0.0001 -318.2546  -99.3454   True
#      2      3   -235.8    0.0 -345.2546 -126.3454   True
# --------------------------------------------------------

# %% [markdown]
# #### **Thus the hardness of implants with method3 is different from method 1 and method2 irrespective of using any of the alloys**

# %% [markdown]
# ##### **Creating a new column 'class' representing the dentists and methods combinations - ALLOY1**

# %%
ddalloy1['class'] = np.where((ddalloy1['Dentist'] == 1) & (ddalloy1['Method'] == 1), 'D1M1',
                             np.where((ddalloy1['Dentist'] == 1) & (ddalloy1['Method'] == 2), 'D1M2',                            
                             np.where((ddalloy1['Dentist'] == 1) & (ddalloy1['Method'] == 3), 'D1M3',
                             np.where((ddalloy1['Dentist'] == 2) & (ddalloy1['Method'] == 1), 'D2M1',
                             np.where((ddalloy1['Dentist'] == 2) & (ddalloy1['Method'] == 2), 'D2M2',
                             np.where((ddalloy1['Dentist'] == 2) & (ddalloy1['Method'] == 3), 'D2M3',
                             np.where((ddalloy1['Dentist'] == 3) & (ddalloy1['Method'] == 1), 'D3M1',
                             np.where((ddalloy1['Dentist'] == 3) & (ddalloy1['Method'] == 2), 'D3M2',
                             np.where((ddalloy1['Dentist'] == 3) & (ddalloy1['Method'] == 3), 'D3M3',
                             np.where((ddalloy1['Dentist'] == 4) & (ddalloy1['Method'] == 1), 'D4M1',
                             np.where((ddalloy1['Dentist'] == 4) & (ddalloy1['Method'] == 2), 'D4M2',
                             np.where((ddalloy1['Dentist'] == 4) & (ddalloy1['Method'] == 3), 'D4M3',
                             np.where((ddalloy1['Dentist'] == 5) & (ddalloy1['Method'] == 1), 'D5M1',
                             np.where((ddalloy1['Dentist'] == 5) & (ddalloy1['Method'] == 2), 'D5M2', 'D5M3'))))))))))))))

# %%
ddalloy1.tail()
# Out:
#    Dentist Method Alloy  Temp  Response class
# 79       5      2     1  1600       665  D5M2
# 80       5      2     1  1700       752  D5M2
# 84       5      3     1  1500       421  D5M3
# 85       5      3     1  1600       483  D5M3
# 86       5      3     1  1700       405  D5M3

# %%
#import the required function
from statsmodels.stats.multicomp import pairwise_tukeyhsd

# perform multiple pairwise comparison (Tukey HSD)
m_comp = pairwise_tukeyhsd(endog = ddalloy1['Response'], groups = ddalloy1['class'], alpha = 0.05)
print(m_comp)
# Out:
#    Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2  meandiff p-adj    lower     upper   reject
# ---------------------------------------------------------
#   D1M1   D1M2     -84.0 0.9933 -332.8283  164.8283  False
#   D1M1   D1M3  -63.3333 0.9996 -312.1617   185.495  False
#   D1M1   D2M1     -22.0    1.0 -270.8283  226.8283  False
#   D1M1   D2M2  -33.3333    1.0 -282.1617   215.495  False
#   D1M1   D2M3     -58.0 0.9999 -306.8283  190.8283  False
#   D1M1   D3M1  -91.6667 0.9853  -340.495  157.1617  False
#   D1M1   D3M2     -76.0 0.9975 -324.8283  172.8283  False
#   D1M1   D3M3  -76.6667 0.9972  -325.495  172.1617  False
#   D1M1   D4M1  -33.3333    1.0 -282.1617   215.495  False
#   D1M1   D4M2  -17.6667    1.0  -266.495  231.1617  False
#   D1M1   D4M3 -302.6667  0.007  -551.495  -53.8383   True
#   D1M1   D5M1  -92.3333 0.9844 -341.1617   156.495  False
#   D1M1   D5M2     -59.0 0.9998 -307.8283  189.8283  False
# ...

# %% [markdown]
# While using ALLOY-1 for treating the dental cavities
#
# The response of hardness of dental implants differs for the following combinations of dentists and methods
#
# *	 Dentist 1 with Method 1 and Dentist 4 with Method 3
# *	 Dentist 1 with Method 1 and Dentist 5 with Method 3
# *    Dentist 1 with Method 2 and Dentist 5 with Method 3
# *	 Dentist 1 with Method 3 and Dentist 5 with Method 3
# *	 Dentist 2 with Method 1 and Dentist 4 with Method 3
# *	 Dentist 2 with Method 1 and Dentist 5 with Method 3
# *	 Dentist 2 with Method 2 and Dentist 4 with Method 3
# *	 Dentist 2 with Method 2 and Dentist 5 with Method 3
# *	 Dentist 2 with Method 3 and Dentist 5 with Method 3
# *	 Dentist 3 with Method 1 and Dentist 5 with Method 3
# *	 Dentist 3 with Method 2 and Dentist 5 with Method 3
# *	 Dentist 3 with Method 3 and Dentist 5 with Method 3
# *	 Dentist 4 with Method 1 and Dentist 4 with Method 3
# *	 Dentist 4 with Method 1 and Dentist 5 with Method 3
# *	 Dentist 4 with Method 2 and Dentist 4 with Method 3
# *	 Dentist 4 with Method 2 and Dentist 5 with Method 3
# *	 Dentist 5 with Method 1 and Dentist 5 with Method 3
# *	 Dentist 5 with Method 2 and Dentist 5 with Method 3

# %% [markdown]
# ##### **Creating a new column 'class' representing the dentists and methods combinations - ALLOY2**

# %%
ddalloy2['class'] = np.where((ddalloy2['Dentist'] == 1) & (ddalloy2['Method'] == 1), 'D1M1',
                             np.where((ddalloy2['Dentist'] == 1) & (ddalloy2['Method'] == 2), 'D1M2',                            
                             np.where((ddalloy2['Dentist'] == 1) & (ddalloy2['Method'] == 3), 'D1M3',
                             np.where((ddalloy2['Dentist'] == 2) & (ddalloy2['Method'] == 1), 'D2M1',
                             np.where((ddalloy2['Dentist'] == 2) & (ddalloy2['Method'] == 2), 'D2M2',
                             np.where((ddalloy2['Dentist'] == 2) & (ddalloy2['Method'] == 3), 'D2M3',
                             np.where((ddalloy2['Dentist'] == 3) & (ddalloy2['Method'] == 1), 'D3M1',
                             np.where((ddalloy2['Dentist'] == 3) & (ddalloy2['Method'] == 2), 'D3M2',
                             np.where((ddalloy2['Dentist'] == 3) & (ddalloy2['Method'] == 3), 'D3M3',
                             np.where((ddalloy2['Dentist'] == 4) & (ddalloy2['Method'] == 1), 'D4M1',
                             np.where((ddalloy2['Dentist'] == 4) & (ddalloy2['Method'] == 2), 'D4M2',
                             np.where((ddalloy2['Dentist'] == 4) & (ddalloy2['Method'] == 3), 'D4M3',
                             np.where((ddalloy2['Dentist'] == 5) & (ddalloy2['Method'] == 1), 'D5M1',
                             np.where((ddalloy2['Dentist'] == 5) & (ddalloy2['Method'] == 2), 'D5M2', 'D5M3'))))))))))))))

# %%
ddalloy2.tail()
# Out:
#    Dentist Method Alloy  Temp  Response class
# 82       5      2     2  1600       933  D5M2
# 83       5      2     2  1700       835  D5M2
# 87       5      3     2  1500       536  D5M3
# 88       5      3     2  1600       405  D5M3
# 89       5      3     2  1700       312  D5M3

# %%
#import the required function
from statsmodels.stats.multicomp import pairwise_tukeyhsd

# perform multiple pairwise comparison (Tukey HSD)
m_comp = pairwise_tukeyhsd(endog = ddalloy2['Response'], groups = ddalloy2['class'], alpha = 0.05)
print(m_comp)
# Out:
#    Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2  meandiff p-adj    lower     upper   reject
# ---------------------------------------------------------
#   D1M1   D1M2   95.3333  0.999 -245.5625  436.2292  False
#   D1M1   D1M3 -180.6667 0.8085 -521.5625  160.2292  False
#   D1M1   D2M1   37.6667    1.0 -303.2292  378.5625  False
#   D1M1   D2M2       5.0    1.0 -335.8958  345.8958  False
#   D1M1   D2M3 -140.3333 0.9635 -481.2292  200.5625  False
#   D1M1   D3M1  -63.3333    1.0 -404.2292  277.5625  False
#   D1M1   D3M2     -27.0    1.0 -367.8958  313.8958  False
#   D1M1   D3M3 -104.6667 0.9973 -445.5625  236.2292  False
#   D1M1   D4M1  -66.3333    1.0 -407.2292  274.5625  False
#   D1M1   D4M2    2.3333    1.0 -338.5625  343.2292  False
#   D1M1   D4M3 -231.3333 0.4686 -572.2292  109.5625  False
#   D1M1   D5M1      52.0    1.0 -288.8958  392.8958  False
#   D1M1   D5M2   19.3333    1.0 -321.5625  360.2292  False
# ...

# %% [markdown]
# While using ALLOY-2 for treating the dental cavities
#
# The response of hardness of dental implants differs for the following combinations of dentists and methods
#
# *	 Dentist 1 with Method 1 and Dentist 5 with Method 3
# *	 Dentist 1 with Method 2 and Dentist 5 with Method 3
# *	 Dentist 2 with Method 1 and Dentist 5 with Method 3
# *	 Dentist 2 with Method 2 and Dentist 5 with Method 3
# *	 Dentist 3 with Method 1 and Dentist 5 with Method 3
# *	 Dentist 3 with Method 2 and Dentist 5 with Method 3
# *	 Dentist 4 with Method 1 and Dentist 5 with Method 3
# *	 Dentist 4 with Method 2 and Dentist 5 with Method 3
# *	 Dentist 5 with Method 1 and Dentist 5 with Method 3
# *	 Dentist 5 with Method 2 and Dentist 5 with Method 3

# %% [markdown]
# #### **STEP 6: Interaction levels between Dentist and Method, Alloy and Method, Dentist and Alloy.**

# %% [markdown]
# ##### **Interaction levels between Dentist and Method - Alloy1**

# %%
### ALLOY-1
from statsmodels.graphics.factorplots import interaction_plot
interaction_plot(np.array(ddalloy1['Dentist']),np.array(ddalloy1['Method']),np.array(ddalloy1['Response']),markers=['D','^','o'])

# %% [markdown]
# ##### **Interaction levels between Dentist and Method - Alloy2**

# %%
### ALLOY-2
from statsmodels.graphics.factorplots import interaction_plot
interaction_plot(np.array(ddalloy2['Dentist']),np.array(ddalloy2['Method']),np.array(ddalloy2['Response']),markers=['D','^','o'])

# %% [markdown]
# ##### **Interaction levels between Alloy and Method**

# %%
### ALLOY-1
from statsmodels.graphics.factorplots import interaction_plot
interaction_plot(np.array(dd['Alloy']),np.array(dd['Method']),np.array(dd['Response']),markers=['D','^','o'])

# %% [markdown]
# ##### **Interaction levels between Dentist and Alloy**

# %%
### ALLOY-1
from statsmodels.graphics.factorplots import interaction_plot
interaction_plot(np.array(dd['Alloy']),np.array(dd['Dentist']),np.array(dd['Response']))

# %% [markdown]
# *	There is some sort of  interaction between dentist and method while using alloy-1
# *	There is no interaction between dentist and method while using alloy-2
# *	There is some sort of interaction between alloy-1 and methods 1& 2
# *	There is no interaction between alloy-2 and any of the three methods
# *	There is some sort of interaction between alloy-2 and dentists 1& 2
# *	There is no interaction between alloy-1 and any of the five dentists

# %%
#Analysis of interaction effect between dentist and the alloy 
formula = 'Response ~ C(Dentist) + C(Alloy) + C(Dentist):C(Alloy)'
model = ols(formula, dd).fit()
aov_table = anova_lm(model)
print(aov_table)
# Out:
#                        df        sum_sq        mean_sq         F    PR(>F)
# C(Dentist)            4.0  1.577946e+05   39448.638889  1.945921  0.110853
# C(Alloy)              1.0  1.058155e+05  105815.511111  5.219663  0.024982
# C(Dentist):C(Alloy)   4.0  5.687044e+03    1421.761111  0.070133  0.990853
# Residual             80.0  1.621798e+06   20272.480556       NaN       NaN

# %% [markdown]
# With P-Value greater than 0.005 there is no interaction between dentist and alloys. The effect of choosing a dentist to treat dental cavity does not depend on the alloy used by the dentist

# %%
#Analysis of interaction effect between dentist and the alloy 
formula = 'Response ~ C(Method) + C(Alloy) + C(Method):C(Alloy)'
model = ols(formula, dd).fit()
aov_table = anova_lm(model)
print(aov_table)
# Out:
#                       df        sum_sq        mean_sq          F        PR(>F)
# C(Method)            2.0  5.934275e+05  296713.744444  21.917576  2.189867e-08
# C(Alloy)             1.0  1.058155e+05  105815.511111   7.816354  6.415387e-03
# C(Method):C(Alloy)   2.0  5.468509e+04   27342.544444   2.019732  1.390848e-01
# Residual            84.0  1.137167e+06   13537.707937        NaN           NaN

# %% [markdown]
# With P-Value less than 0.005 there is  interaction between alloys and methods. The effect of the method is related to the alloy used and it reflects on the hardness of implants.

# %%
#Analysis of interaction effect between dentist and the alloy 
formula = 'Response ~ C(Dentist) + C(Method) + C(Dentist):C(Method)'
model = ols(formula, ddalloy1).fit()
aov_table = anova_lm(model)
print(aov_table)
# Out:
#                         df         sum_sq       mean_sq          F    PR(>F)
# C(Dentist)             4.0  106683.688889  26670.922222   3.899638  0.011484
# C(Method)              2.0  148472.177778  74236.088889  10.854287  0.000284
# C(Dentist):C(Method)   8.0  185941.377778  23242.672222   3.398383  0.006793
# Residual              30.0  205180.000000   6839.333333        NaN       NaN

# %% [markdown]
# With P-Value greater than 0.005 there is no interaction between dentist and methods using alloy1. The hardness of implants does not depend on the dentist and the method

# %%
#Analysis of interaction effect between dentist and the alloy 
formula = 'Response ~ C(Dentist) + C(Method) + C(Dentist):C(Method)'
model = ols(formula, ddalloy2).fit()
aov_table = anova_lm(model)
print(aov_table)
# Out:
#                         df         sum_sq        mean_sq          F    PR(>F)
# C(Dentist)             4.0   56797.911111   14199.477778   1.106152  0.371833
# C(Method)              2.0  499640.400000  249820.200000  19.461218  0.000004
# C(Dentist):C(Method)   8.0  197459.822222   24682.477778   1.922787  0.093234
# Residual              30.0  385104.666667   12836.822222        NaN       NaN

# %% [markdown]
# With P-Value greater than 0.005 there is no interaction between dentist and methods using alloy2. The hardness of implants does not depend on the dentist and the method
